# %%
import numpy as np
import pandas as pd
import os 
import glob
import pdb
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
import scipy as sp
from scipy.special import expit
import sys
sys.path.append(os.path.dirname(os.getcwd()))
from visualisation_and_evaluation.helpers_eval import extract_scores, wa, select_best_run
from visualisation_and_evaluation.helpers_vizualisation import plot_scores

# %%
path_scores = r'../eval_scores'

# %%
files = [x for x in os.listdir(path_scores) if 'score' in x]
selection_method = 'wa' #'wa' (weighted average), 'div' (based on divergence score only)
eval_all = pd.read_csv(os.path.join(path_scores, 'scores_baselines_full.csv'), index_col=[0])
eval_all['silhouette_score_neg'] = -eval_all['silhouette_score']
fname = files[0]
print(fname)
# Out:
# scores_autoencoder_gan_narrower_batchnorm_toy.csv

# %%
files = [x for x in os.listdir(path_scores) if 'score' in x]
selection_method = 'wa' #'wa' (weighted average), 'div' (based on divergence score only)
eval_all = pd.read_csv(os.path.join(path_scores, 'scores_baselines_full.csv'), index_col=[0])
eval_all['silhouette_score_neg'] = -eval_all['silhouette_score']
best_epochs = []
for fname in files:
    if('baselines' in fname or 'csv' not in fname):
        continue
    print(fname)
    df = extract_scores(path_scores, fname)
    # select "the best run"
    df_best = select_best_run(df, method=selection_method)
    epoch = df_best.index[0]
    best_epochs.append([fname, epoch])
    df_best = df_best.loc[:,eval_all.columns]
    eval_all = eval_all.append(df_best)
eval_all = eval_all.sort_values(['method','sample']).reset_index(drop=True)
# add the weighted averaged score
eval_all['wa'] = eval_all[['divergence_score', 'entropy_score', 'silhouette_score_neg']].apply(lambda x: wa(x), axis=1)
eval_all
# Out:
# scores_autoencoder_gan_narrower_batchnorm_toy.csv
# scores_autoencoder_gan_narrower_batchnorm_toy_subset.csv
# scores_autoencoder_gan_narrower_full_sample5.csv
# scores_autoencoder_gan_narrower_full_sample65.csv
# scores_autoencoder_gan_narrower_full_sample75.csv
# scores_autoencoder_gan_wider_batchnorm_toy.csv
# scores_autoencoder_gan_wider_batchnorm_toy_subset.csv
# scores_autoencoder_gan_wider_full_sample5.csv
# scores_autoencoder_gan_wider_full_sample65.csv
# scores_autoencoder_gan_wider_full_sample75.csv
# scores_residual_gan_full_panels_sample5.csv
# scores_residual_gan_full_panels_sample65.csv
# scores_residual_gan_full_panels_sample75.csv
# scores_residual_gan_toy_sample1.csv
# scores_residual_gan_toy_subset_sample1.csv
# C:\Users\heida\Documents\ETH\Deep Learning\2019_DL_Class\visualisation_and_evaluation\helpers_eval.py:205: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.index_name = ['epoch']
# scores_residual_gan_wo_residuals_full_panels_sample5.csv
# scores_residual_gan_wo_residuals_full_panels_sample65.csv
# scores_residual_gan_wo_residuals_full_panels_sample75.csv
# scores_residual_gan_wo_residuals_full_panels_toy_sample1.csv
# scores_residual_gan_wo_residuals_toy_subset_sample1.csv
# scores_vanilla_gan_batchnorm_full_upsample_sample5.csv
# scores_vanilla_gan_batchnorm_full_upsample_sample65.csv
# scores_vanilla_gan_batchnorm_full_upsample_sample75.csv
# scores_vanilla_gan_batchnorm_toy.csv
# scores_vanilla_gan_batchnorm_toy_subset.csv
#     divergence_score  entropy_score  \
# 0           0.505870       0.567308
# 1           0.666738      -1.000000
# 2           0.195629       0.632716
# 3           0.144000       0.637359
# 4           0.094076       0.670433
# 5           0.061244       0.674565
# 6           0.071145      -1.000000
# 7           0.077308       0.679926
# 8           0.092479       0.673803
# 9           0.052506       0.672774
# 10          0.365523       0.562519
# 11          0.356872       0.534817
# 12          0.339301       0.567231
# 13          0.746074       0.606468
# 14          0.823479       0.625791
# 15          1.226742       0.581923
# 16          1.709039       0.408511
# 17          1.999101       0.483480
# 18          2.320436       0.522710
# 19          2.004377       0.154429
# 20          2.755214       0.172126
# 21          2.244114       0.083538
# 22          0.101398       0.682603
# 23          0.125604       0.652526
# 24          0.087863       0.676411
# 25          0.060172      -1.000000
# 26          0.050457       0.675075
# 27          0.392449       0.491119
# 28          0.136517       0.656895
# 29          0.063426       0.676152
# 30          0.216434      -1.000000
# 31          0.198479       0.640554
# 32          0.165495       0.677695
# 33          0.175986       0.656250
# 34          0.186429       0.661489
# 35          0.097782       0.669972
# 36          0.119481      -1.000000
#
#                                                method    sample  \
# 0   autoencoder gan narrower batchnorm toy subset.csv    subset
# 1          autoencoder gan narrower batchnorm toy.csv       toy
# 2                       autoencoder gan narrower full   sample5
# 3                       autoencoder gan narrower full  sample65
# 4                       autoencoder gan narrower full  sample75
# 5      autoencoder gan wider batchnorm toy subset.csv    subset
# 6             autoencoder gan wider batchnorm toy.csv       toy
# 7                          autoencoder gan wider full   sample5
# 8                          autoencoder gan wider full  sample65
# 9                          autoencoder gan wider full  sample75
# 10                                             combat   sample5
# 11                                             combat  sample65
# 12                                             combat  sample75
# 13                                                mnn   sample5
# 14                                                mnn  sample65
# 15                                                mnn  sample75
# 16                                                raw   sample5
# 17                                                raw  sample65
# 18                                                raw  sample75
# 19                                                reg   sample5
# 20                                                reg  sample65
# 21                                                reg  sample75
# 22                           residual gan full panels   sample5
# 23                           residual gan full panels  sample65
# 24                           residual gan full panels  sample75
# 25                                   residual gan toy   sample1
# 26                            residual gan toy subset   sample1
# 27              residual gan wo residuals full panels   sample5
# 28              residual gan wo residuals full panels  sample65
# 29              residual gan wo residuals full panels  sample75
# 30          residual gan wo residuals full panels toy   sample1
# 31               residual gan wo residuals toy subset   sample1
# 32                vanilla gan batchnorm full upsample   sample5
# 33                vanilla gan batchnorm full upsample  sample65
# 34                vanilla gan batchnorm full upsample  sample75
# 35               vanilla gan batchnorm toy subset.csv    subset
# 36                      vanilla gan batchnorm toy.csv       toy
#
#     silhouette_score  silhouette_score_neg        wa
# 0          -0.079052              0.079052  0.607312
# 1          -0.048829              0.048829  0.513510
# 2           0.070364             -0.070364  0.566791
# 3           0.080273             -0.080273  0.560204
# 4          -0.184280              0.184280  0.569419
# 5          -0.081062              0.081062  0.560461
# 6          -0.070570              0.070570  0.443099
# 7           0.048765             -0.048765  0.556338
# 8           0.039221             -0.039221  0.558297
# 9          -0.279672              0.279672  0.569092
# 10          0.199534             -0.199534  0.576355
# 11          0.227501             -0.227501  0.571997
# 12          0.057563             -0.057563  0.580570
# 13          0.199215             -0.199215  0.623374
# 14          0.155583             -0.155583  0.635184
# 15          0.051759             -0.051759  0.676489
# 16          0.191738             -0.191738  0.694017
# 17          0.116330             -0.116330  0.720112
# 18         -0.070170              0.070170  0.747119
# 19          0.197928             -0.197928  0.692323
# 20          0.159304             -0.159304  0.725033
# 21          0.018921             -0.018921  0.707387
# 22          0.096919             -0.096919  0.557118
# 23          0.052853             -0.052853  0.560312
# 24         -0.170494              0.170494  0.568361
# 25         -0.043241              0.043241  0.440363
# 26         -0.073137              0.073137  0.558753
# 27          0.046993             -0.046993  0.582198
# 28          0.078378             -0.078378  0.560690
# 29         -0.296361              0.296361  0.571500
# 30         -0.036618              0.036618  0.459462
# 31         -0.066697              0.066697  0.574526
# 32         -0.119699              0.119699  0.575585
# 33         -0.025702              0.025702  0.570752
# 34         -0.296221              0.296221  0.585819
# 35         -0.093997              0.093997  0.565358
# 36         -0.042641              0.042641  0.447732

# %%
best_epochs
# Out:
# [['scores_autoencoder_gan_narrower_batchnorm_toy.csv', 50],
#  ['scores_autoencoder_gan_narrower_batchnorm_toy_subset.csv', 50],
#  ['scores_autoencoder_gan_narrower_full_sample5.csv', 50],
#  ['scores_autoencoder_gan_narrower_full_sample65.csv', 350],
#  ['scores_autoencoder_gan_narrower_full_sample75.csv', 700],
#  ['scores_autoencoder_gan_wider_batchnorm_toy.csv', 250],
#  ['scores_autoencoder_gan_wider_batchnorm_toy_subset.csv', 50],
#  ['scores_autoencoder_gan_wider_full_sample5.csv', 150],
#  ['scores_autoencoder_gan_wider_full_sample65.csv', 250],
#  ['scores_autoencoder_gan_wider_full_sample75.csv', 900],
#  ['scores_residual_gan_full_panels_sample5.csv', 375],
#  ['scores_residual_gan_full_panels_sample65.csv', 475],
#  ['scores_residual_gan_full_panels_sample75.csv', 425],
#  ['scores_residual_gan_toy_sample1.csv', 175],
#  ['scores_residual_gan_toy_subset_sample1.csv', 100],
#  ['scores_residual_gan_wo_residuals_full_panels_sample5.csv', 150],
#  ['scores_residual_gan_wo_residuals_full_panels_sample65.csv', 300],
#  ['scores_residual_gan_wo_residuals_full_panels_sample75.csv', 900],
#  ['scores_residual_gan_wo_residuals_full_panels_toy_sample1.csv', 525],
#  ['scores_residual_gan_wo_residuals_toy_subset_sample1.csv', 350],
#  ['scores_vanilla_gan_batchnorm_full_upsample_sample5.csv', 800],
#  ['scores_vanilla_gan_batchnorm_full_upsample_sample65.csv', 700],
#  ['scores_vanilla_gan_batchnorm_full_upsample_sample75.csv', 500],
#  ['scores_vanilla_gan_batchnorm_toy.csv', 600],
#  ['scores_vanilla_gan_batchnorm_toy_subset.csv', 600]]

# %%
fname
# Out:
# 'summary_scores_wa_toy.png'
